# %%
import torch

# 1) load it back
sd = torch.load(
    "./output/Med3DVLM‑Qwen‑2.5‑7B‑lora‑adapter/model_with_lora.bin",
    map_location="cpu",
)

# 2) print how many keys, plus names & shapes
print(f"Loaded {len(sd)} tensors:")
for name, tensor in sd.items():
    print(f"  {name:60s} — {tuple(tensor.shape)}")
