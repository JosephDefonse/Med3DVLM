# %%
import torch

# 1) load it back
sd = torch.load(
    "./output/Med3DVLM-Qwen-2.5-7B-finetune/model_with_lora.bin",
    map_location="cpu",
)

# 2) print how many keys, plus names & shapes
print(f"Loaded {len(sd)} tensors:")
for name, tensor in sd.items():
    print(f"  {name:60s} — {tuple(tensor.shape)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import torch
#       3 # 1) load it back
# ----> 4 sd = torch.load(
#       5     "iq38_scratch/biomed_model_pmct/data/med3dvlm/Med3DVLM/output/Med3DVLM-Qwen-2.5-7B-finetune/model_with_lora.bin",
#       6     map_location="cpu",
#       7 )
#       9 # 2) print how many keys, plus names & shapes
#      10 print(f"Loaded {len(sd)} tensors:")
#
# File /fs04/scratch2/iq38/biomed_model_pmct/data/minigptmed/MiniGPT-Med/miniconda3/miniconda/conda/envs/med3dvlm/lib/python3.12/site-packages/torch/serialization.py:1425, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1422 if "encoding" not in pickle_load_args.keys():
#    1423     pickle_load_args["encoding"] = "utf-8"
# -> 1425 with _open_file_like(f, "rb") as opened_file:
#    1426     if _is_zipfile(opened_file):
#    1427         # The zipfile reader is going to advance the current file position.
#    1428         # If we want to actually tail call to torch.jit.load, we need to
#    1429         # reset back to the original position.
#    1430         orig_position = opened_file.tell()
#
# File /fs04/scratch2/iq38/biomed_model_pmct/data/minigptmed/MiniGPT-Med/miniconda3/miniconda/conda/envs/med3dvlm/lib/python3.12/site-packages/torch/serialization.py:751, in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# File /fs04/scratch2/iq38/biomed_model_pmct/data/minigptmed/MiniGPT-Med/miniconda3/miniconda/conda/envs/med3dvlm/lib/python3.12/site-packages/torch/serialization.py:732, in _open_file.__init__(self, name, mode)
#     731 def __init__(self, name, mode):
# --> 732     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iq38_scratch/biomed_model_pmct/data/med3dvlm/Med3DVLM/output/Med3DVLM-Qwen-2.5-7B-finetune/model_with_lora.bin'
