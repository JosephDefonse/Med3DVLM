# %%
from src.model.llm import VLMQwenForCausalLM
from transformers import AutoTokenizer

model = VLMQwenForCausalLM.from_pretrained("models/Med3DVLM")
tokenizer = AutoTokenizer.from_pretrained("models/Med3DVLM", use_fast=False)

total = sum(p.numel() for p in model.parameters())
print(f"→ Successfully re‑loaded merged model with {total:,} total parameters")
# Out:
# Loading checkpoint shards: 100%|██████████| 7/7 [00:01<00:00,  6.48it/s]
# → Successfully re‑loaded merged model with 7,678,229,696 total parameters

# %%
inputs = tokenizer("Hello, world!", return_tensors="pt")
outputs = model(**inputs)
print("→ logits shape:", outputs.logits.shape)
# Out:
# → logits shape: torch.Size([1, 4, 151666])

# %%
merged_sd = model.state_dict()
print("Merged state‐dict contains", len(merged_sd), "tensors")
# and compare to your reload:
reloaded = AutoModelForCausalLM.from_pretrained("models/Med3DVLM")
print("Reloaded state‐dict contains", len(reloaded.state_dict()), "tensors")
# Out:
# Merged state‐dict contains 813 tensors
# Loading checkpoint shards: 100%|██████████| 7/7 [00:01<00:00,  6.24it/s]
# Reloaded state‐dict contains 813 tensors
